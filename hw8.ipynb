# %% [markdown]
# # Практическое задание #8
# # Работа с БД
# ##    Установить библиотеку psycopg2 (pip install psycopg2-binary)
# ##    Подключиться к БД - 1 балл

# %%
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading https://files.pythonhosted.org/packages/65/4f/083f6b652b7fbecec1dc10bc9d1ffb66efd63611a25dddd0b4c1ef043ba6/psycopg2_binary-2.9.9-cp37-cp37m-win_amd64.whl (1.2MB)
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 24.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import psycopg2
import pandas as pd

# %%
host = 'hh-pgsql-public.ebi.ac.uk'
port = 5432
database = 'pfmegrnargs'
user = 'reader'
password = 'NWDMCE5xdipIjRrp'

# %%
try:
    conn = psycopg2.connect(dbname=database, user=user, password=password, host=host)
except:
    print('Can`t establish connection to database')

# %% [markdown]
# ##    Получите 10 строк из таблицы rnc_database - 2 балла

# %%
with conn.cursor() as cursor:
    query = "SELECT * FROM rnc_database limit 10"
    cursor.execute(query)
    rnc_db = cursor.fetchall()

# %% [markdown]
# ##    Сохраните полученные данные в pd.DataFrame - 1 балл

# %%
rnc_df = pd.DataFrame(rnc_db)
rnc_df.head()
# Out:
#    0                          1       2          3    4          5  6     7   \
# 0   1 2017-05-01 00:00:00.000000  RNACEN        ENA  884        ENA  Y
# 1   5 2017-05-17 00:00:00.000000  RNACEN       VEGA   98       VEGA  N
# 2  26 2017-05-01 00:00:00.000000  RNACEN    GENCODE  450    GENCODE  N
# 3  55 2023-10-10 15:02:45.191606  RNACEN     MGNIFY  839     MGnify  Y  None
# 4  41 2017-05-01 00:00:00.000000  RNACEN  GENECARDS  867  MalaCards  Y
#
#           8          9       10    11        12        13      14  \
# 0        ENA              412.0  10.0  900074.0  12086180  814855
# 1       VEGA  PRJEB4568     NaN   NaN       NaN         0       0
# 2    GENCODE              889.0  32.0  205012.0     47677       2
# 3     MGnify       None   151.0  27.0    3514.0    135924    1929
# 4  GeneCards             1298.0  16.0  347561.0    517673       1
#
#                                                   15  \
# 0  provides a comprehensive record of the world's...
# 1  is a repository for high-quality gene models p...
# 2  produces high quality reference gene annotatio...
# 3                                               None
# 4  is a searchable, integrative database that pro...
#
#                                    16  \
# 0  https://www.ebi.ac.uk/ena/browser/
# 1           http://vega.sanger.ac.uk/
# 2            http://gencodegenes.org/
# 3                                None
# 4          https://www.genecards.org/
#
#                                                   17  \
# 0  [{'upi': 'URS00002D0E0C', 'taxid': 10090}, {'u...
# 1  [{'upi': 'URS00000B15DA', 'taxid': 9606}, {'up...
# 2  [{'upi': 'URS00000B15DA', 'taxid': 9606}, {'up...
# 3                                               None
# 4  [{'upi': 'URS0000EBFCE3', 'taxid': 9606}, {'up...
#
#                                                   18
# 0  [{'title': 'The European Nucleotide Archive in...
# 1  [{'title': 'The GENCODE v7 catalog of human lo...
# 2  [{'title': 'GENCODE: the reference human genom...
# 3                                               None
# 4  [{'title': 'The GeneCards Suite: From Gene Dat...

# %% [markdown]
#   ##  Получите значения столбцов display_name, num_sequences, num_organisms, , url для 10 строк из таблицы rnc_database - 2 балла

# %%
with conn.cursor() as cursor:
    query = "SELECT display_name, num_sequences, num_organisms, url FROM rnc_database limit 10"
    cursor.execute(query)
    rnc_selected_columns = cursor.fetchall()

# %%
rnc_selected_columns_df = pd.DataFrame(rnc_selected_columns)
rnc_selected_columns_df.columns = ['display_name', 'num_sequences', 'num_organisms', 'url']
rnc_selected_columns_df
# Out:
#       display_name  num_sequences  num_organisms  \
# 0              ENA       12086180         814855
# 1             VEGA              0              0
# 2          GENCODE          47677              2
# 3           MGnify         135924           1929
# 4        GeneCards         517673              1
# 5              RDP           4779           2487
# 6        LNCipedia         126876              1
# 7  snoRNA Database            680             10
# 8             Rfam        1879595          14792
# 9          piRBase         200827             17
#
#                                             url
# 0            https://www.ebi.ac.uk/ena/browser/
# 1                     http://vega.sanger.ac.uk/
# 2                      http://gencodegenes.org/
# 3                                          None
# 4                    https://www.genecards.org/
# 5                       http://rdp.cme.msu.edu/
# 6                     http://www.lncipedia.org/
# 7             http://lowelab.ucsc.edu/snoRNAdb/
# 8                               http://rfam.org
# 9  http://www.regulatoryrna.org/database/piRNA/

# %% [markdown]
# # Работа с API
# ##    Изучить документацию API OF ICE AND FIRE
#
# ##    Получить информацию обо всех книгах и сохранить в pd.DataFrame - 1 балл

# %%
import requests

# %%
api_base_url = 'https://www.anapioficeandfire.com/api'

# %%
books_list = requests.get(
    f'{api_base_url}/books'
).json()

# %%
db_books = pd.DataFrame(books_list)
db_books
# Out:
#                  authors                                         characters  \
# 0  [George R. R. Martin]  [https://www.anapioficeandfire.com/api/charact...
# 1  [George R. R. Martin]  [https://www.anapioficeandfire.com/api/charact...
# 2  [George R. R. Martin]  [https://www.anapioficeandfire.com/api/charact...
# 3  [George R. R. Martin]  [https://www.anapioficeandfire.com/api/charact...
# 4  [George R. R. Martin]  [https://www.anapioficeandfire.com/api/charact...
# 5  [George R. R. Martin]  [https://www.anapioficeandfire.com/api/charact...
# 6  [George R. R. Martin]  [https://www.anapioficeandfire.com/api/charact...
# 7  [George R. R. Martin]  [https://www.anapioficeandfire.com/api/charact...
# 8  [George R. R. Martin]  [https://www.anapioficeandfire.com/api/charact...
# 9  [George R. R. Martin]  [https://www.anapioficeandfire.com/api/charact...
#
#          country            isbn     mediaType                        name  \
# 0  United States  978-0553103540     Hardcover           A Game of Thrones
# 1  United States  978-0553108033      Hardback            A Clash of Kings
# 2  United States  978-0553106633     Hardcover           A Storm of Swords
# 3  United States  978-0976401100  GraphicNovel            The Hedge Knight
# 4  United Status  978-0553801507     Hardcover           A Feast for Crows
# 5  United States  978-0785126508     Hardcover             The Sworn Sword
# 6  United States  978-0765360267     Paperback          The Mystery Knight
# 7  United States  978-0553801477     Hardcover        A Dance with Dragons
# 8  United States  978-0765332066     Hardcover  The Princess and the Queen
# 9  United States  978-0345537263     Hardcover            The Rogue Prince
#
#    numberOfPages                                      povCharacters  \
# 0            694  [https://www.anapioficeandfire.com/api/charact...
# 1            768  [https://www.anapioficeandfire.com/api/charact...
# 2            992  [https://www.anapioficeandfire.com/api/charact...
# 3            164  [https://www.anapioficeandfire.com/api/charact...
# 4            784  [https://www.anapioficeandfire.com/api/charact...
# 5            152  [https://www.anapioficeandfire.com/api/charact...
# 6            416  [https://www.anapioficeandfire.com/api/charact...
# 7           1040  [https://www.anapioficeandfire.com/api/charact...
# 8            784                                                 []
# 9            832                                                 []
#
#                    publisher             released  \
# 0               Bantam Books  1996-08-01T00:00:00
# 1               Bantam Books  1999-02-02T00:00:00
# 2               Bantam Books  2000-10-31T00:00:00
# 3  Dabel Brothers Publishing  2005-03-09T00:00:00
# 4               Bantam Books  2005-11-08T00:00:00
# 5                     Marvel  2008-06-18T00:00:00
# 6                Tor Fantasy  2011-03-29T00:00:00
# 7               Bantam Books  2011-07-12T00:00:00
# 8                  Tor Books  2013-12-03T00:00:00
# 9               Bantam Books  2014-06-17T00:00:00
#
#                                               url
# 0   https://www.anapioficeandfire.com/api/books/1
# 1   https://www.anapioficeandfire.com/api/books/2
# 2   https://www.anapioficeandfire.com/api/books/3
# 3   https://www.anapioficeandfire.com/api/books/4
# 4   https://www.anapioficeandfire.com/api/books/5
# 5   https://www.anapioficeandfire.com/api/books/6
# 6   https://www.anapioficeandfire.com/api/books/7
# 7   https://www.anapioficeandfire.com/api/books/8
# 8   https://www.anapioficeandfire.com/api/books/9
# 9  https://www.anapioficeandfire.com/api/books/10

# %% [markdown]
# ## Получить информацию обо всех домах Вестероса (Houses) и сохранить в pd.DataFrame - 1 балл

# %%
houses_list = requests.get(
    f'{api_base_url}/houses'
).json()
db_houses = pd.DataFrame(houses_list)
db_houses.head()
# Out:
#   ancestralWeapons cadetBranches  \
# 0               []            []
# 1               []            []
# 2               []            []
# 3               []            []
# 4               []            []
#
#                                           coatOfArms  \
# 0  A golden wreath, on a blue field with a gold b...
# 1          Gyronny Gules and Sable, a hand couped Or
# 2
# 3                             Or, semy of ants gules
# 4  Or, an apple tree eradicated proper fructed gu...
#
#                                          currentLord diedOut founded founder  \
# 0
# 1  https://www.anapioficeandfire.com/api/characte...
# 2
# 3  https://www.anapioficeandfire.com/api/characte...
# 4
#
#                                                 heir  \
# 0
# 1  https://www.anapioficeandfire.com/api/characte...
# 2
# 3
# 4
#
#                           name  \
# 0                 House Algood
# 1  House Allyrion of Godsgrace
# 2                  House Amber
# 3                House Ambrose
# 4   House Appleton of Appleton
#
#                                            overlord           region  \
# 0  https://www.anapioficeandfire.com/api/houses/229  The Westerlands
# 1  https://www.anapioficeandfire.com/api/houses/285            Dorne
# 2                                                          The North
# 3  https://www.anapioficeandfire.com/api/houses/398        The Reach
# 4  https://www.anapioficeandfire.com/api/houses/398        The Reach
#
#          seats                                       swornMembers titles  \
# 0           []                                                 []     []
# 1  [Godsgrace]  [https://www.anapioficeandfire.com/api/charact...     []
# 2           []                                                 []     []
# 3           []  [https://www.anapioficeandfire.com/api/charact...     []
# 4   [Appleton]                                                 []     []
#
#                                               url            words
# 0  https://www.anapioficeandfire.com/api/houses/1
# 1  https://www.anapioficeandfire.com/api/houses/2  No Foe May Pass
# 2  https://www.anapioficeandfire.com/api/houses/3
# 3  https://www.anapioficeandfire.com/api/houses/4    Never Resting
# 4  https://www.anapioficeandfire.com/api/houses/5

# %% [markdown]
# ##     Получить информацию обо всех домах Вестероса, у которых есть девиз, и сохранить в pd.DataFrame - 2 балла

# %%
houses_list = requests.get(
    f'{api_base_url}/houses?haswords=true'
).json()
db_houses = pd.DataFrame(houses_list)
db_houses.head()
# Out:
#   ancestralWeapons                                      cadetBranches  \
# 0               []                                                 []
# 1               []                                                 []
# 2               []   [https://www.anapioficeandfire.com/api/houses/6]
# 3               []                                                 []
# 4               []  [https://www.anapioficeandfire.com/api/houses/...
#
#                                           coatOfArms  \
# 0          Gyronny Gules and Sable, a hand couped Or
# 1                             Or, semy of ants gules
# 2  A sky-blue falcon soaring against a white moon...
# 3  Tenny, a sun in splendour beneath a chevron in...
# 4  A black crowned stag, on a gold field(Or, a st...
#
#                                          currentLord diedOut  \
# 0  https://www.anapioficeandfire.com/api/characte...
# 1  https://www.anapioficeandfire.com/api/characte...
# 2  https://www.anapioficeandfire.com/api/characte...
# 3
# 4  https://www.anapioficeandfire.com/api/characte...
#
#                 founded                                            founder  \
# 0
# 1
# 2  Coming of the Andals  https://www.anapioficeandfire.com/api/characte...
# 3
# 4                  1 AC  https://www.anapioficeandfire.com/api/characte...
#
#                                                 heir  \
# 0  https://www.anapioficeandfire.com/api/characte...
# 1
# 2  https://www.anapioficeandfire.com/api/characte...
# 3
# 4  https://www.anapioficeandfire.com/api/characte...
#
#                              name  \
# 0     House Allyrion of Godsgrace
# 1                   House Ambrose
# 2        House Arryn of the Eyrie
# 3        House Ashford of Ashford
# 4  House Baratheon of Storm's End
#
#                                            overlord          region  \
# 0  https://www.anapioficeandfire.com/api/houses/285           Dorne
# 1  https://www.anapioficeandfire.com/api/houses/398       The Reach
# 2   https://www.anapioficeandfire.com/api/houses/16        The Vale
# 3  https://www.anapioficeandfire.com/api/houses/398       The Reach
# 4   https://www.anapioficeandfire.com/api/houses/16  The Stormlands
#
#                                                seats  \
# 0                                        [Godsgrace]
# 1                                                 []
# 2   [The Eyrie (summer), Gates of the Moon (winter)]
# 3                                          [Ashford]
# 4  [Storm's End, Dragonstone (House Baratheon of ...
#
#                                         swornMembers  \
# 0  [https://www.anapioficeandfire.com/api/charact...
# 1  [https://www.anapioficeandfire.com/api/charact...
# 2  [https://www.anapioficeandfire.com/api/charact...
# 3  [https://www.anapioficeandfire.com/api/charact...
# 4  [https://www.anapioficeandfire.com/api/charact...
#
#                                               titles  \
# 0                                                 []
# 1                                                 []
# 2  [King of Mountain and Vale (formerly), Lord of...
# 3                                  [Lord of Ashford]
# 4  [Lord of Storm's End, Lord Paramount of the St...
#
#                                                url                  words
# 0   https://www.anapioficeandfire.com/api/houses/2        No Foe May Pass
# 1   https://www.anapioficeandfire.com/api/houses/4          Never Resting
# 2   https://www.anapioficeandfire.com/api/houses/7       As High as Honor
# 3   https://www.anapioficeandfire.com/api/houses/8  Our Sun Shines Bright
# 4  https://www.anapioficeandfire.com/api/houses/17       Ours is the Fury
